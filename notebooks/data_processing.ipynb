# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
import re
from sklearn.model_selection import train_test_split

# %%
# Load the data
# Data path
data_path = 'data/teach AI 12.12.23.csv'
data = pd.read_csv(data_path)
data.head()
# Out:
#                                        POST___TRAVEL  \
# 0  We travellee to australia, the country was hot...
# 1  Recently went to Iceland and can't believe how...
# 2  So excited to pick up my new BMW. It will be g...
# 3     Time travelling in thf future and back in time
# 4           barcelona is my favourite place to visit
#
#                                      POST___ABORTION   ADM   RIV  \
# 0  Banning abortion is against human rights if ch...  3,33  2,78
# 1  Once again, men are dictating what women shoul...  2,78  1,22
# 2  Very unsure on the new government legislation....  3,22  1,44
# 3    Don't agree . There should be freedom of choice  3,89  2,67
# 4  everyone has a right to bodily autonomy - bann...  1,44  1,78
#
#                          ID CNI_check GCB_check_ Progress  Finished  Gender  \
# 0  63e55ecaa002eb54284210e8    #NULL!     #NULL!   100,00         1       1
# 1  60562563c658b51a10bc7a4d         6          2   100,00         1       2
# 2  654fa30e4eaf197c8678b860         6          2   100,00         1       2
# 3  637f7c2db2e351960e722a15         6          2   100,00         1       1
# 4  60bf0f6824fa105c814baabc         6          4   100,00         1       1
#
#    ... Other_portals_6  Other_portals_7  Other_portals_7_TEXT CNI_MEAN  \
# 0  ...          #NULL!           #NULL!                   NaN     3,69
# 1  ...               1           #NULL!                   NaN     5,06
# 2  ...               1           #NULL!                   NaN     4,06
# 3  ...          #NULL!           #NULL!                   NaN     4,25
# 4  ...          #NULL!           #NULL!                   NaN     4,06
#
#   FFNI___SSF_2_R  FFNI_Antagonism FFNI_Neurotic  FFNI_Agentic GCB_MEAN  \
# 0           4,00             2,86          3,33          3,75     5,00
# 1           2,00             1,29          1,33          3,25     2,87
# 2           4,00             1,57          4,00          3,75     3,13
# 3           3,00             2,71          3,67          3,50     1,20
# 4           3,00             2,86          3,33          3,50     4,00
#
#    PUR_MEAN
# 0      3,67
# 1      1,80
# 2      2,93
# 3      2,53
# 4      3,07
#
# [5 rows x 36 columns]

# %%
# Analyze the data
# Check the data types
# Check the missing values
data.replace('#NULL!', np.nan, inplace=True)
data.isnull().sum()
# Out:
# POST___TRAVEL                 0
# POST___ABORTION               0
# ADM                           0
# RIV                           0
# ID                            0
# CNI_check                    47
# GCB_check_                   47
# Progress                      0
# Finished                      0
# Gender                        0
# Gender_3_TEXT               183
# Age                           0
# Ethnic_background             0
# Ethnic_background_8_TEXT    179
# Location                      0
# Education                     0
# Education_6_TEXT            181
# Employment                    0
# Employment_7_TEXT           174
# Marital_status                0
# Twitter                       0
# Other_portals_1             177
# Other_portals_2              50
# Other_portals_3              44
# Other_portals_4             113
# Other_portals_5             107
# Other_portals_6             125
# Other_portals_7             168
# Other_portals_7_TEXT        168
# CNI_MEAN                      0
# FFNI___SSF_2_R                0
# FFNI_Antagonism               0
# FFNI_Neurotic                 0
# FFNI_Agentic                  0
# GCB_MEAN                      0
# PUR_MEAN                      0
# dtype: int64

# %%
# Get columns
data.columns
# Out:
# Index(['POST___TRAVEL', 'POST___ABORTION', 'ADM', 'RIV', 'ID', 'CNI_check',
#        'GCB_check_', 'Progress', 'Finished', 'Gender', 'Gender_3_TEXT', 'Age',
#        'Ethnic_background', 'Ethnic_background_8_TEXT', 'Location',
#        'Education', 'Education_6_TEXT', 'Employment', 'Employment_7_TEXT',
#        'Marital_status', 'Twitter', 'Other_portals_1', 'Other_portals_2',
#        'Other_portals_3', 'Other_portals_4', 'Other_portals_5',
#        'Other_portals_6', 'Other_portals_7', 'Other_portals_7_TEXT',
#        'CNI_MEAN', 'FFNI___SSF_2_R', 'FFNI_Antagonism', 'FFNI_Neurotic',
#        'FFNI_Agentic', 'GCB_MEAN', 'PUR_MEAN'],
#       dtype='object')

# %%
# List of not needed columns to drop:
columns_to_drop = ['ID','CNI_check','GCB_check_','Progress','Finished','Location']
data.drop(columns=columns_to_drop, inplace=True)
data.head(2)
# Out:
#                                        POST___TRAVEL  \
# 0  We travellee to australia, the country was hot...
# 1  Recently went to Iceland and can't believe how...
#
#                                      POST___ABORTION   ADM   RIV  Gender  \
# 0  Banning abortion is against human rights if ch...  3,33  2,78       1
# 1  Once again, men are dictating what women shoul...  2,78  1,22       2
#
#   Gender_3_TEXT  Age  Ethnic_background Ethnic_background_8_TEXT  Education  \
# 0           NaN   38                  1                      NaN          2
# 1           NaN   28                  8                  British          1
#
#    ... Other_portals_6  Other_portals_7 Other_portals_7_TEXT  CNI_MEAN  \
# 0  ...             NaN              NaN                  NaN      3,69
# 1  ...               1              NaN                  NaN      5,06
#
#    FFNI___SSF_2_R FFNI_Antagonism FFNI_Neurotic FFNI_Agentic GCB_MEAN PUR_MEAN
# 0            4,00            2,86          3,33         3,75     5,00     3,67
# 1            2,00            1,29          1,33         3,25     2,87     1,80
#
# [2 rows x 30 columns]

# %%
def clean(review):
    review = review.lower()
    review = re.sub('[^a-z A-Z 0-9-]+', '', review)
    review = " ".join([word for word in review.split() 
                       if word not in stopwords.words('english')])
    return review

# %%
data['POST___ABORTION'] = data['POST___ABORTION'].apply(clean)
data['POST___TRAVEL'] = data['POST___TRAVEL'].apply(clean)
data.head(2)
# Out:
#                                        POST___TRAVEL  \
# 0  travellee australia country hot amazing love b...
# 1  recently went iceland cant believe beautiful l...
#
#                                      POST___ABORTION   ADM   RIV  Gender  \
# 0  banning abortion human rights choice awful wom...  3,33  2,78       1
# 1                         men dictating women bodies  2,78  1,22       2
#
#   Gender_3_TEXT  Age  Ethnic_background Ethnic_background_8_TEXT  Education  \
# 0           NaN   38                  1                      NaN          2
# 1           NaN   28                  8                  British          1
#
#    ... Other_portals_6  Other_portals_7 Other_portals_7_TEXT  CNI_MEAN  \
# 0  ...             NaN              NaN                  NaN      3,69
# 1  ...               1              NaN                  NaN      5,06
#
#    FFNI___SSF_2_R FFNI_Antagonism FFNI_Neurotic FFNI_Agentic GCB_MEAN PUR_MEAN
# 0            4,00            2,86          3,33         3,75     5,00     3,67
# 1            2,00            1,29          1,33         3,25     2,87     1,80
#
# [2 rows x 30 columns]

# %%
# Divide the data for validation and testing
# Split the data into training and testing sets
X = data['POST___ABORTION']
y = data['POST___TRAVEL']
train, validate = np.split(data.sample(frac=1,random_state=47), [int(.8*len(data))])

train.reset_index(drop=True, inplace=True)
validate.reset_index(drop=True, inplace=True)
# Out:
# /home/maciej/anaconda3/envs/studybase/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
# check the shape of the data
print(train.shape)
print(validate.shape)
# Out:
# (148, 30)
# (37, 30)

# %%
# TODO: Remove the most common words from the data (as abortion, goverment,
#       women, right, choice, amazing, time, beautiful, etc.)

# %%
# Save the data
train.to_csv('data/processed_data.csv', index=False)
validate.to_csv('data/processed_data_validate.csv', index=False)
